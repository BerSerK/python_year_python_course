# %%
import sklearn.datasets
pd_df = sklearn.datasets.load_iris(as_frame=True).frame
pd_df.to_csv('iris.csv', index=False)
pd_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %% [markdown]
# 1. 安装java8: https://www.openlogic.com/openjdk-downloads
# 2. 安装spark: https://spark.apache.org/downloads.html?source=post_page-----595bb6067de7-------------------------------- 添加环境变量HADOOP_HOME 和SPARK_HOME
# 3. 安装pyspark
#
# ```
#   ! pip install pyspark
# ```

# %%
import os
import pyspark
from pyspark.sql import SparkSession

os.environ["PYSPARK_PYTHON"] = f"f:\\anaconda"

# 创建 SparkSession 对象，这是与 Spark 交互的入口
spark = SparkSession.builder \
   .appName("MyFirstPySparkApp") \
   .master("local[*]") \
   .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[4], line 6
#       1 from pyspark.sql import SparkSession
#       2 # 创建 SparkSession 对象，这是与 Spark 交互的入口
#       3 spark = SparkSession.builder \
#       4    .appName("MyFirstPySparkApp") \
#       5    .master("local[*]") \
# ----> 6    .getOrCreate()
#
# File f:\anaconda3\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# File f:\anaconda3\Lib\site-packages\pyspark\context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
# ...
